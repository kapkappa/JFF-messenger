# %%
import flask
import time
from datetime import datetime

# %%
from flask import Flask
from flask import request

app = Flask(__name__)
db = []

def shutdown_server():
    func = request.environ.get('werkzeug.server.shutdown')
    if func is None:
        raise RuntimeError('Not running with the Werkzeug Server')
    func()

@app.route('/shutdown', methods=['GET'])
def shutdown():
    shutdown_server()
    return 'Server shutting down...'

@app.route("/")
def hello():
    return """Добро пожаловать на сервер!
    <a href='/status'>Статус</a>
    <a href='/shutdown'>Shutdown</a>
    <a href='/messages'>Messages</a>"""

@app.route("/status")
def status():
    dn = datetime.now()
    st = {
        'Status' : True,
        'Name' : 'Messenger',
        'Time' : dn.strftime('%d.%m.%Y %H:%M:%S')
    }
    return st

@app.route('/send', methods=['POST'])
def send():
    data = request.json
    
    db.append({
        'id' : len(db), #Идентификатор - размер базы данных, т.е. номер элемента в базе данных
        'name' : data['name'],
        'text' : data['text'],
        'timestamp' : time.time()
    })
    return {'OK':True}

@app.route('/messages')
def messages():
    if 'after_id' in request.args:
        after_id = int(request.args['after_id']) + 1
    else:
        after_id = 0
    
    return {'messages': db[after_id:]}

# %%
app.run(debug=False)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [08/Sep/2020 21:49:56] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:49:58] "GET /messages HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:50:05] "POST /send HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:50:06] "POST /send HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:50:06] "POST /send HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:50:11] "GET /messages?after_id=-1 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:50:18] "GET /messages?after_id=-1 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:50:21] "GET /messages?after_id=2 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:50:24] "GET /messages?after_id=2 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:50:27] "GET /messages?after_id=2 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:50:29] "POST /send HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:50:30] "GET /messages?after_id=2 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:50:33] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:50:34] "GET /messages HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:50:36] "GET /status HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:50:36] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:50:39] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:50:42] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:50:45] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:50:48] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:50:51] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:50:54] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:50:57] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:51:00] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:51:04] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:51:07] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:51:10] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:51:13] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:51:16] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:51:19] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:51:22] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:51:25] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:51:28] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:51:31] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:51:34] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:51:37] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:51:40] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:51:44] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:51:47] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:51:48] "GET /messages HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:51:50] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:51:53] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:51:56] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:51:59] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:52:02] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:52:05] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:52:08] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:52:11] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:52:15] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:52:18] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:52:21] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:52:24] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:52:27] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:52:30] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:52:33] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:52:36] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:52:39] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:52:42] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:52:43] "POST /send HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:52:45] "GET /messages?after_id=3 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:52:48] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:52:51] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:52:54] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:52:57] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:52:58] "GET /messages HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:53:00] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:53:03] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:53:06] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:53:09] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:53:12] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:53:15] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:53:18] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:53:21] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:53:24] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:53:27] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:53:30] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:53:33] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:53:36] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:53:39] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:53:42] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:53:45] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:53:48] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:53:51] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:53:54] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:53:57] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:54:00] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:54:03] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:54:06] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:54:09] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:54:12] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:54:15] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:54:18] "GET /messages?after_id=4 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2020 21:54:19] "GET /shutdown HTTP/1.1" 200 -
